# %% [markdown]
# # Data Validation
# The goal is to run validations on the datasets to identify the issues and identify cleaning techniques

# %%
from diabetes_classifier.dataset import load_datasets
from diabetes_classifier.validation import run_all_validations

# %% [markdown]
# ## Load Datasets

# %%
df_prediction, df_brfss2015, df_brfss2021 = load_datasets()

# %% [markdown]
# ## Run Validation

# %%
results = run_all_validations(
    {
        "diabetes_prediction": df_prediction,
        "diabetes_brfss2015": df_brfss2015,
        "diabetes_brfss2021": df_brfss2021,
    },
    open_docs=True,
)
